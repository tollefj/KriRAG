# %%
def make_url(offset):
    return f"https://lovdata.no/register/avgjørelser?verdict=TRA&offset={offset}#doclistheader"

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
# gather 100 documents:

def get_documents(start_idx, end_idx):
    if end_idx < start_idx:
        raise ValueError("end_idx must be greater than start_idx")

    # if startidx is 100, and end_idx is 200, we want to get 100 documents
    # that is, using the offset of 20
    # we need to define the number of iterations 
    num_iter = (end_idx - start_idx) // 20
    # the start_idx defines our starting offset
    start_offset = start_idx // 20
    print(f"Iterating {num_iter} times, starting at offset {start_offset}")
    documents = []

    for i in range(num_iter):
        offset = (start_offset + i) * 20
        res = requests.get(make_url(offset))
        print(res.url)
        soup = bs(res.text, 'html.parser')
        _d = soup.find_all('a', href=lambda href: href and '/dokument/' in href)
        # just extract the href
        _d = [d['href'] for d in _d]
        print(f"found {len(_d)} documents")
        documents.extend(_d)
        offset += 20
    return documents

documents = get_documents(100, 200)
# Out:
# Iterating 5 times, starting at offset 5
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=100#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=120#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=140#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=160#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=180#doclistheader
# found 20 documents

# %%
import unicodedata
import re

def make_case_url(id):
    return f"https://lovdata.no{id}"

def get_unescaped_text(tag):
    return unicodedata.normalize("NFKD", tag.text)

def extract_div_data(div):
    current_paragraph = []

    # find any h-tag, such as h1, h2, h3,...
    htags = div.find_all(re.compile('^h[1-6]$'))
    if len(htags) == 0:
        title = "Missing title"
    else:
        title = htags[0].text

    for p in div.find_all('p'):
        if len(p.text) > 0:
            current_paragraph.append(get_unescaped_text(p))
    
    return {
        "title": title,
        "content": current_paragraph
    }
    

def extract_case_data(id):
    url = make_case_url(id)
    print(url)
    res = requests.get(url)
    soup = bs(res.text, 'html.parser')
    # get the div id="documentBody"
    doc_body = soup.find('div', id='documentBody')
    # for each <div> with the attribute data-level, create a new paragraph
    # all tags occurring before the first <div> are considered introduction material
    introduction = []
    paragraphs = {}

    if not doc_body:
        return

    doc_body_children = doc_body.find_all(recursive=False)
    for child in doc_body_children:
        if child.name != 'div':
            if len(child.text) > 0:
                introduction.append(get_unescaped_text(child))
        else:
            # look one layer further, in case there's divs under this div:
            if not child:
                continue
            subdivs = child.find_all(recursive=False)
            subdivs = [s for s in subdivs if s.name == 'div']
            for s in subdivs:
                data_id = s.get('data-id', s.get('id', 'no-id'))
                paragraphs[data_id] = extract_div_data(s)
            else:
                data_id = child.get('data-id', child.get('id', 'no-id'))
                paragraphs[data_id] = extract_div_data(child)

    return {
        "id": id,
        "introduction": introduction,
        "paragraphs": paragraphs,
    }

# %%
documents[0]
# Out:
# '/dokument/TRSTR/avgjorelse/ttel-2022-148789'

# %%
import os
import json
from datetime import datetime

date_str = datetime.now().strftime("%Y_%b_%d")
lovdata_gathering = f"../data/lovdata/scraped/{date_str}"
os.makedirs(lovdata_gathering, exist_ok=True)

# get 100 documents from the starting position 0 to 100 (5 offset iterations)
documents = get_documents(0, 300)
for case in documents:
    case_id = case.split('/')[-1]
    doc_path = os.path.join(lovdata_gathering, f"{case_id}.json")
    data = extract_case_data(case)
    if data:
        with open(doc_path, 'w', encoding="utf-8") as f:
            f.write(json.dumps(data, ensure_ascii=False))
# Out:
# Iterating 15 times, starting at offset 0
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=0#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=20#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=40#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=60#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=80#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=100#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=120#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=140#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=160#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=180#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=200#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=220#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=240#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=260#doclistheader
# found 20 documents
# https://lovdata.no/register/avgj%C3%B8relser?verdict=TRA&offset=280#doclistheader
# found 20 documents
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-184227
# https://lovdata.no/dokument/TRSIV/avgjorelse/ttro-2022-180530
# https://lovdata.no/dokument/TRSTR/avgjorelse/ttro-2022-176914
# https://lovdata.no/dokument/TRSIV/avgjorelse/trog-2022-151705
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-169851
# https://lovdata.no/dokument/TRSIV/avgjorelse/thod-2022-52415
# https://lovdata.no/dokument/TRSIV/avgjorelse/tmha-2023-8564
# https://lovdata.no/dokument/TRSIV/avgjorelse/tnts-2022-143447
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-182065
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-162782
# https://lovdata.no/dokument/TRSTR/avgjorelse/tmor-2022-163432
# https://lovdata.no/dokument/TRSIV/avgjorelse/ttel-2022-62922-2
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-49383
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-157778
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-124847
# https://lovdata.no/dokument/TRSIV/avgjorelse/thod-2022-17149
# https://lovdata.no/dokument/TRSIV/avgjorelse/trab-2022-124216
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-146392
# https://lovdata.no/dokument/TRSIV/avgjorelse/thod-2022-42494
# https://lovdata.no/dokument/TRSTR/avgjorelse/tiof-2022-150030
# https://lovdata.no/dokument/TRSIV/avgjorelse/thod-2022-42494
# https://lovdata.no/dokument/TRSTR/avgjorelse/tiof-2022-150030
# https://lovdata.no/dokument/TRSTR/avgjorelse/trog-2022-159959
# https://lovdata.no/dokument/TRSTR/avgjorelse/trog-2022-76748
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-180565
# https://lovdata.no/dokument/TRSTR/avgjorelse/tnts-2022-181750
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2023-9319
# https://lovdata.no/dokument/TRSIV/avgjorelse/toin-2021-186415
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-89886
# https://lovdata.no/dokument/TRSTR/avgjorelse/tagd-2023-14900
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-92378
# https://lovdata.no/dokument/TRSTR/avgjorelse/tnts-2023-12191
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-116094
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2021-78701
# https://lovdata.no/dokument/TRSTR/avgjorelse/thos-2022-71642-3
# https://lovdata.no/dokument/TRSTR/avgjorelse/ttel-2022-145502
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-98231
# https://lovdata.no/dokument/TRSTR/avgjorelse/tbus-2023-8190
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-147898
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-147348
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2020-90284-2
# https://lovdata.no/dokument/TRSTR/avgjorelse/tvin-2022-175733
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-128463
# https://lovdata.no/dokument/TRSIV/avgjorelse/thod-2022-138692
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2021-152781
# https://lovdata.no/dokument/TRSTR/avgjorelse/trog-2022-164623
# https://lovdata.no/dokument/TRSTR/avgjorelse/trab-2022-143250
# https://lovdata.no/dokument/TRSTR/avgjorelse/tsos-2022-163306
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-189572
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-66147
# https://lovdata.no/dokument/TRSTR/avgjorelse/ttro-2023-6395
# https://lovdata.no/dokument/TRSTR/avgjorelse/trab-2022-161908
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2023-3398
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-170123
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-15379
# https://lovdata.no/dokument/TRSTR/avgjorelse/toin-2022-180491
# https://lovdata.no/dokument/TRSTR/avgjorelse/tiof-2022-146642
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-131348
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-120011
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-16834
# https://lovdata.no/dokument/TRSIV/avgjorelse/ttel-2022-12640
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-186124
# https://lovdata.no/dokument/TRSTR/avgjorelse/tvin-2022-153742
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2023-5054
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-154383
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-112381
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2020-177975
# https://lovdata.no/dokument/TRSTR/avgjorelse/tbus-2022-159784
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-152320
# https://lovdata.no/dokument/TRSTR/avgjorelse/tvin-2022-135157
# https://lovdata.no/dokument/TRSTR/avgjorelse/tsro-2022-166312
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-167201
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-159317
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-109747
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-101805-2
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-182102
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-165338
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-56544
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-38199
# https://lovdata.no/dokument/TRSIV/avgjorelse/tvin-2022-129314
# https://lovdata.no/dokument/TRSTR/avgjorelse/trog-2022-134178
# https://lovdata.no/dokument/TRSTR/avgjorelse/tnts-2022-151540
# https://lovdata.no/dokument/TRSTR/avgjorelse/tagd-2022-179243
# https://lovdata.no/dokument/TRSTR/avgjorelse/tagd-2022-171783
# https://lovdata.no/dokument/TRSTR/avgjorelse/trog-2022-124526
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-189681-2
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-158390
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022-86849
# https://lovdata.no/dokument/TRSIV/avgjorelse/tsro-2022-70706
# https://lovdata.no/dokument/TRSTR/avgjorelse/thos-2023-2260
# https://lovdata.no/dokument/TRSTR/avgjorelse/toin-2022-186461
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-155305
# https://lovdata.no/dokument/TRSTR/avgjorelse/thod-2022-133510
# https://lovdata.no/dokument/TRSIV/avgjorelse/tsro-2022-85027
# https://lovdata.no/dokument/TRSTR/avgjorelse/tosl-2022-58042
# https://lovdata.no/dokument/TRSIV/avgjorelse/tosl-2022